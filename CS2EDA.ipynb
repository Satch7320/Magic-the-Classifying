# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bulk = pd.read_json('data/all-cards-20210329091415.json')

# %%
bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315455 entries, 0 to 315454
# Data columns (total 78 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   object             315455 non-null  object
#  1   id                 315455 non-null  object
#  2   oracle_id          315455 non-null  object
#  3   multiverse_ids     315455 non-null  object
#  4   mtgo_id            31823 non-null   float64
#  5   mtgo_foil_id       24254 non-null   float64
#  6   tcgplayer_id       51650 non-null   float64
#  7   cardmarket_id      48233 non-null   float64
#  8   name               315455 non-null  object
#  9   lang               315455 non-null  object
#  10  released_at        315455 non-null  datetime64[ns]
#  11  uri                315455 non-null  object
#  12  scryfall_uri       315455 non-null  object
#  13  layout             315455 non-null  object
#  14  highres_image      315455 non-null  bool
# ...

# %%
english_bulk = pd.read_csv('data/en_cards.csv')

# %%
english_bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56200 entries, 0 to 56199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      56200 non-null  int64
#  1   name            56200 non-null  object
#  2   lang            56200 non-null  object
#  3   released_at     56200 non-null  object
#  4   mana_cost       47746 non-null  object
#  5   cmc             56200 non-null  float64
#  6   type_line       56200 non-null  object
#  7   oracle_text     53810 non-null  object
#  8   power           26439 non-null  object
#  9   toughness       26439 non-null  object
#  10  colors          55707 non-null  object
#  11  color_identity  56200 non-null  object
#  12  keywords        56200 non-null  object
#  13  set             56200 non-null  object
#  14  rarity          56200 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 6.4+ MB

# %%
relevant_cols = ['name', 'released_at', 'mana_cost', 
                 'cmc', 'type_line', 'oracle_text', 'power', 'toughness', 
                 'colors', 'color_identity', 'keywords', 'set', 'rarity', 'flavor_text']

# %%
en_df = bulk[bulk['lang']=='en']

# %%
for_csv = en_df[relevant_cols]

# %%
for_csv.to_csv('data/en_cards.csv', index = False)

# %%
type(df['mana_cost'][0])

# %%
categorical_cols = ['mana_cost', 'type_line', 'colors', 'color_identity', 'rarity']

# %%
dum_df = pd.get_dummies(english_bulk, columns = categorical_cols, drop_first = True)

# %%
dum_df.head(2)
# Out:
#    Unnamed: 0           name lang released_at  cmc  \
# 0           0    Fury Sliver   en  2006-10-06  6.0
# 1           1  Kor Outfitter   en  2009-10-02  2.0
#
#                                          oracle_text power toughness keywords  \
# 0           All Sliver creatures have double strike.     3         3       []
# 1  When Kor Outfitter enters the battlefield, you...     2         2       []
#
#    set  ...  color_identity_['R']  color_identity_['U', 'W']  \
# 0  tsp  ...                     1                          0
# 1  zen  ...                     0                          0
#
#    color_identity_['U']  color_identity_['W']  color_identity_[]  \
# 0                     0                     0                  0
# 1                     0                     1                  0
#
#    rarity_common  rarity_mythic  rarity_rare  rarity_special  rarity_uncommon
# 0              0              0            0               0                1
# ...

# %%
dum_df.drop(['Unnamed: 0'], axis = 1)
# Out:
#                       name lang released_at  cmc  \
# 0              Fury Sliver   en  2006-10-06  6.0
# 1            Kor Outfitter   en  2009-10-02  2.0
# 2                   Spirit   en  2015-05-22  0.0
# 3            Siren Lookout   en  2017-09-29  3.0
# 4                      Web   en  1994-04-01  1.0
# ...                    ...  ...         ...  ...
# 56195           Hollow One   en  2020-08-13  5.0
# 56196         Angel's Tomb   en  2015-07-17  3.0
# 56197       Celestine Reef   en  2009-09-04  0.0
# 56198         Horned Troll   en  2003-07-28  3.0
# 56199  Exultant Skymarcher   en  2018-01-19  3.0
#
#                                              oracle_text power toughness  \
# 0               All Sliver creatures have double strike.     3         3
# 1      When Kor Outfitter enters the battlefield, you...     2         2
# 2                                                 Flying     1         1
# 3      Flying\nWhen Siren Lookout enters the battlefi...     1         2
# ...

# %%
dum_df.to_csv('data/dum_cards.csv')
